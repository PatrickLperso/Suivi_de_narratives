# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
data=pd.read_csv("medias_per_coutries.csv")
data.dtypes
# Out:
# Unnamed: 0          int64
# media_coverage     object
# url                object
# media_name         object
# media_type         object
# media_subject      object
# media_language     object
# media_diffusion    object
# media_location     object
# coverage           object
# true_country       object
# dtype: object

# %%
data.loc[:, ["media_language", "true_country"]].value_counts()["ENG"].plot.pie()
# Out:
# <AxesSubplot:ylabel='count'>

# %%
data.loc[:, "media_language"].value_counts().iloc[:25].plot.bar()
# Out:
# <AxesSubplot:xlabel='media_language'>

# %% [markdown]
# """ Media Type
# BC-Broadcast
# IN-Internet
# MG-Magazine
# NP-Newspaper
# PA-Press Agency 	Media Focus
# AG-Agriculture
# AL-Alternative
# BU-Business
# ET-Ethnic
# GI-General Interest
# SP-Sport 	Language
# ARA-Arabic
# DEU-German
# ENG-English
# FRA-French
# POR-Portuguese
# SPA-Spanish """

# %%
data.loc[:, "media_subject"].value_counts().iloc[:25].plot.bar()
# Out:
# <AxesSubplot:xlabel='media_subject'>

# %%
data.loc[:, "media_type"].value_counts().iloc[:25].plot.bar()
# Out:
# <AxesSubplot:xlabel='media_type'>

# %%
len(data)
# Out:
# 21898
