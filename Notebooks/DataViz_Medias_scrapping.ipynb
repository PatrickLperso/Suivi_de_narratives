# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
data=pd.read_csv("../data/medias_per_countries.csv")
data.dtypes
# Out:
# id                  int64
# media_coverage     object
# url                object
# media_name         object
# media_type         object
# media_subject      object
# media_language     object
# media_diffusion    object
# media_location     object
# coverage           object
# true_country       object
# dtype: object

# %% [markdown]
# ## Nombres d'entrées non nulles

# %%
(~data.isna()).sum()
# Out:
# id                 21898
# media_coverage     21829
# url                21898
# media_name         21898
# media_type         21699
# media_subject      21699
# media_language     21699
# media_diffusion     3322
# media_location     17428
# coverage           17428
# true_country       21898
# dtype: int64

# %% [markdown]
# ## Liste de Médias Francais s'exprimant en anglais

# %%
data[(data.loc[:, "true_country"]=="China") & (data.loc[:, "media_language"]=="ENG") ]
# Out:
#         id media_coverage                                                url  \
# 7919  7919       National                           http://english.cctv.com/
# 7932  7932       National                           http://www.china.org.cn/
# 7934  7934       National              http://www.china-business-market.com/
# 7935  7935       National                          http://www.chinanews.net/
# 7936  7936       National                http://www.thechinaperspective.com/
# 7942  7942       National                        http://www.visiontimes.com/
# 7948  7948       National                        http://www.bjreview.com.cn/
# 7949  7949       National                        http://english.qstheory.cn/
# 7954  7954       National                         http://www.globaltimes.cn/
# 7958  7958       National                    http://english.chinamil.com.cn/
# 7966  7966       National                      http://english.people.com.cn/
# 7979  7979       National                      http://usa.chinadaily.com.cn/
# 7984  7984       National                            http://english.news.cn/
# 8003  8003          Hefei                      http://english.anhuinews.com/
# 8014  8014        Beijing                        http://www.beijingnews.net/
# 8019  8019        Beijing                         http://www.globaltimes.cn/
# 8023  8023        Beijing                    http://english.chinamil.com.cn/
# 8028  8028        Beijing                       http://english.qianlong.com/
# 8033  8033        Beijing                      http://english.people.com.cn/
# 8046  8046        Beijing                      http://usa.chinadaily.com.cn/
# 8085  8085       Shenzhen                         http://szdaily.sznews.com/
# 8141  8141       Changsha                          http://english.rednet.cn/
# 8153  8153         Suzhou  http://epaper.subaonet.com/list_more_new.aspx?...
# 8171  8171       Shenyang                   http://www.liaoning-gateway.com/
# 8178  8178      Huhehaote                         http://eng.nmgnews.com.cn/
# 8193  8193          Jinan                           http://shandongnews.com/
# 8201  8201       Shanghai                        http://english.eastday.com/
# 8205  8205       Shanghai                      http://www.shanghaidaily.com/
# 8206  8206       Shanghai                       http://www.shanghainews.net/
# 8207  8207       Shanghai                            http://shanghaiist.com/
# 8229  8229        Tianjin                      http://english.enorth.com.cn/
# 8235  8235         Urumqi                              http://english.ts.cn/
# 8246  8246           Lasa                 http://english.chinatibetnews.com/
# 8260  8260       Hangzhou                http://www.hangzhou.com.cn/english/
# 8289  8289         Ningbo                   http://news.cnnb.com.cn/english/
#
#                          media_name media_type media_subject media_language  \
# 7919                           CCTV         BC            GI            ENG
# 7932                          China         IN            GI            ENG
# 7934          China Business Market         IN            BU            ENG
# 7935                     China News         IN            GI            ENG
# 7936              China Perspective         IN            BU            ENG
# 7942                   Vision Times         IN            GI            ENG
# 7948                 Beijing Review         MG            GI            ENG
# 7949                   Qiushi Zazhi         MG            GI            ENG
# 7954                   Global Times         NP            GI            ENG
# 7958      Jiefangjun Bao - People's         NP            ML            ENG
# 7966  Renmin Ribao - People's Daily         NP            GI            ENG
# 7979   Zhongguo Ribao - China Daily         NP            GI            ENG
# 7984                         Xinhua         PA            GI            ENG
# 8003                     Anhui News         IN            GI            ENG
# 8014                   Beijing News         IN            GI            ENG
# 8019                   Global Times         NP            GI            ENG
# 8023      Jiefangjun Bao - People's         NP            GI            ENG
# 8028                       Qianlong         IN            GI            ENG
# 8033  Renmin Ribao - People's Daily         NP            GI            ENG
# 8046   Zhongguo Ribao - China Daily         NP            GI            ENG
# 8085                 Shenzhen Daily         NP            GI            ENG
# 8141                        Red Net         IN            GI            ENG
# 8153                Suzhou \nReview         NP            GI            ENG
# 8171                            NEN         IN            GI            ENG
# 8178                       NMG News         IN            GI            ENG
# 8193                  Shandong News         IN            GI            ENG
# 8201                        Eastday         IN            GI            ENG
# 8205                 Shanghai Daily         NP            GI            ENG
# 8206                  Shanghai News         NP            GI            ENG
# 8207                    Shanghaiist         IN            GI            ENG
# 8229                        E North         IN            GI            ENG
# 8235                    Tianshannet         IN            GI            ENG
# 8246               China Tibet News         IN            GI            ENG
# 8260                       Hangzhou         IN            GI            ENG
# 8289                           CNNB         IN            GI            ENG
#
#      media_diffusion                   media_location  \
# 7919              TV     China - Broadcast News Media
# 7932             NaN      China - Internet News Media
# 7934             NaN      China - Internet News Media
# 7935             NaN      China - Internet News Media
# 7936             NaN      China - Internet News Media
# 7942             NaN      China - Internet News Media
# 7948             NaN      China - Magazine News Media
# 7949             NaN      China - Magazine News Media
# 7954             NaN     China - Newspaper News Media
# 7958             NaN     China - Newspaper News Media
# 7966             NaN     China - Newspaper News Media
# 7979             NaN     China - Newspaper News Media
# 7984             NaN  China - Press Agency News Media
# 8003             NaN                            Anhui
# 8014             NaN                          Beijing
# 8019             NaN                          Beijing
# 8023             NaN                          Beijing
# 8028             NaN                          Beijing
# 8033             NaN                          Beijing
# 8046             NaN                          Beijing
# 8085             NaN                        Guangdong
# 8141             NaN                            Hunan
# 8153             NaN                          Jiangsu
# 8171             NaN                         Liaoning
# 8178             NaN                       Nei Menggu
# 8193             NaN                         Shandong
# 8201             NaN                         Shanghai
# 8205             NaN                         Shanghai
# 8206             NaN                         Shanghai
# 8207             NaN                         Shanghai
# 8229             NaN                          Tianjin
# 8235             NaN                         Xinjiang
# 8246             NaN                   Xizang - Tibet
# 8260             NaN                         Zhejiang
# 8289             NaN                         Zhejiang
#
#                                                coverage true_country
# 7919  China Newspapers and News Media - National and...        China
# 7932  China Newspapers and News Media - National and...        China
# 7934  China Newspapers and News Media - National and...        China
# 7935  China Newspapers and News Media - National and...        China
# 7936  China Newspapers and News Media - National and...        China
# 7942  China Newspapers and News Media - National and...        China
# 7948  China Newspapers and News Media - National and...        China
# 7949  China Newspapers and News Media - National and...        China
# 7954  China Newspapers and News Media - National and...        China
# 7958  China Newspapers and News Media - National and...        China
# 7966  China Newspapers and News Media - National and...        China
# 7979  China Newspapers and News Media - National and...        China
# 7984  China Newspapers and News Media - National and...        China
# 8003            China Newspapers and News Media - Local        China
# 8014            China Newspapers and News Media - Local        China
# 8019            China Newspapers and News Media - Local        China
# 8023            China Newspapers and News Media - Local        China
# 8028            China Newspapers and News Media - Local        China
# 8033            China Newspapers and News Media - Local        China
# 8046            China Newspapers and News Media - Local        China
# 8085            China Newspapers and News Media - Local        China
# 8141            China Newspapers and News Media - Local        China
# 8153            China Newspapers and News Media - Local        China
# 8171            China Newspapers and News Media - Local        China
# 8178            China Newspapers and News Media - Local        China
# 8193            China Newspapers and News Media - Local        China
# 8201            China Newspapers and News Media - Local        China
# 8205            China Newspapers and News Media - Local        China
# 8206            China Newspapers and News Media - Local        China
# 8207            China Newspapers and News Media - Local        China
# 8229            China Newspapers and News Media - Local        China
# 8235            China Newspapers and News Media - Local        China
# 8246            China Newspapers and News Media - Local        China
# 8260            China Newspapers and News Media - Local        China
# 8289            China Newspapers and News Media - Local        China

# %% [markdown]
# ## Pie Chart des locations de médias parlant en anglais

# %%
list(data.loc[:, ["media_language", "true_country"]].value_counts()["ENG"].iloc[:30].index)
# Out:
# ['United Kingdom',
#  'United States',
#  'Nigeria',
#  'South Africa',
#  'India',
#  'New Zealand',
#  'Philippines',
#  'Zimbabwe',
#  'Ireland',
#  'Australia',
#  'Africa Regional',
#  'Bangladesh',
#  'Canada',
#  'Ghana',
#  'Pakistan',
#  'Zambia',
#  'International',
#  'Asia Regional',
#  'Somalia',
#  'Sri Lanka',
#  'Cuba',
#  'Sierra Leone',
#  'Afghanistan',
#  'Kenya',
#  'Near and Middle East Regional',
#  'Ethiopia',
#  'Spain',
#  'Israel',
#  'Liberia',
#  'China']

# %%
liste_countries=['United Kingdom','United States','Nigeria','South Africa','India','New Zealand','Philippines',
                'Ireland','Australia','Africa Regional','Bangladesh','Canada','Ghana','Pakistan',
                'Zambia','International','Asia Regional','Somalia','Sri Lanka',
                'Cuba','Sierra Leone','Kenya','Near and Middle East Regional',
                'Ethiopia','Spain','Israel','Liberia','China']

df_urls=data.loc[data.loc[:, "true_country"].isin(liste_countries), :]

# %%
df_urls
# Out:
#           id   media_coverage                                      url  \
# 0          0         National                  https://www.abc.net.au/
# 1          1         National  https://www.abc.net.au/radio-australia/
# 2          2         National            https://www.foxsports.com.au/
# 3          3         National                https://www.9news.com.au/
# 4          4         National                  https://www.sbs.com.au/
# ...      ...              ...                                      ...
# 21789  21789           Lusaka                http://www.qfmzambia.com/
# 21790  21790           Lusaka            http://rainbownewszambia.com/
# 21791  21791           Lusaka                  http://www.times.co.zm/
# 21792  21792           Lusaka             https://www.daily-mail.co.zm
# 21793  21793  Chikuni Mission          https://www.chikuniradiozm.org/
#
#                 media_name media_type media_subject media_language  \
# 0                      ABC         BC            GI            ENG
# 1      ABC Radio Australia         BC            GI            ENG
# 2               Fox Sports         BC            SP            ENG
# 3                     Nine         BC            GI            ENG
# 4                      SBS         BC            GI            ENG
# ...                    ...        ...           ...            ...
# 21789                 Q FM         BC            GI            ENG
# 21790    Rainbow Newspaper         NP            GI            ENG
# 21791      Times of Zambia         NP            GI            ENG
# 21792    Zambia Daily Mail         NP            GI            ENG
# 21793        Radio Chikuni         BC            GI            ENG
#
#       media_diffusion media_location  \
# 0            Radio TV            NaN
# 1               Radio            NaN
# 2                  TV            NaN
# 3                  TV            NaN
# 4           Radio\nTV            NaN
# ...               ...            ...
# 21789           Radio         Lusaka
# 21790             NaN         Lusaka
# 21791             NaN         Lusaka
# 21792             NaN         Lusaka
# 21793           Radio       Southern
#
#                                        coverage true_country
# 0                                           NaN    Australia
# 1                                           NaN    Australia
# 2                                           NaN    Australia
# 3                                           NaN    Australia
# 4                                           NaN    Australia
# ...                                         ...          ...
# 21789  Zambia Newspapers and News Media - Local       Zambia
# 21790  Zambia Newspapers and News Media - Local       Zambia
# 21791  Zambia Newspapers and News Media - Local       Zambia
# 21792  Zambia Newspapers and News Media - Local       Zambia
# 21793  Zambia Newspapers and News Media - Local       Zambia
#
# [5803 rows x 11 columns]

# %% [markdown]
# ## Bar Graph des différents languages (Anglais, Espagnol, Francais, portugais, russe, arabe, allemand, chinois)

# %%
data.loc[:, "media_language"].value_counts().iloc[:25].plot.bar()
# Out:
# <Axes: xlabel='media_language'>

# %% [markdown]
# ## Liste non exhaustives d'anaoncronymes
#
#
# Media Type
# <br>
# <br>
# BC-Broadcast
# <br>
# IN-Internet
# <br>
# MG-Magazine
# <br>
# NP-Newspaper
# <br>
# PA-Press Agency
#
# Media Focus
# <br>
# <br>
# AG-Agriculture
# <br>
# AL-Alternative
# <br>
# BU-Business
# <br>
# ET-Ethnic
# <br>
# GI-General Interest
# <br>
# SP-Sport

# %% [markdown]
# ## Barplot du "focus" du médias princiapelement General Interest (GI), business(BU) et sport(SP)

# %%
data.loc[:, "media_subject"].value_counts().iloc[:25].plot.bar()
# Out:
# <Axes: xlabel='media_subject'>

# %% [markdown]
# ## Barplot du type de médias principalement des newspaper (NP), sites internets(IN), broadcast(BC), agence de presse(PA)

# %%
data.loc[:, "media_type"].value_counts().iloc[:25].plot.bar()
# Out:
# <Axes: xlabel='media_type'>
